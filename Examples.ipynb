# %% [markdown]
# <a href="https://colab.research.google.com/github/saianuteju9-source/project_1/blob/main/Examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Numerical calcultions:

a = 5
b = 10

print(a + b)
print(a - b)
print(a * b)
print(a / b)
# Out:
# 15
# -5
# 50
# 0.5
